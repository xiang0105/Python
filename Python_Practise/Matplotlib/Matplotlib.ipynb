# %% [markdown]
# 什麼是 Matplotlib？
#
# Matplotlib 是 Python 中的一個低階圖形繪圖庫，可用作視覺化實用程式。
#
# Matplotlib 由 John D. Hunter 創作。
#
# Matplotlib 是開源的，我們可以自由使用它。
#
# Matplotlib 大部分都是用 python 編寫，為了實現平台相容性，少數部分用 C、Objective-C 和 Javascript 編寫。

# %% [markdown]
# Matplotlib 的安裝
#
# ```cmd
# C:\Users\Your Name>pip install matplotlib
# <!-- 本機安裝 -->
# ```
#
# ```python
# !pip install matplotlib
# # vs code ipynb 安裝方式
# ```
#
# ```python
# pip install matplotlib
# # vs code 安裝方式
# ```

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt # type: ignore
import numpy as np # type: ignore

# %% [markdown]
# 繪製 x 和 y 點
#
# 此plot()函數用於在圖表中繪製點（標記）。
#
# 預設情況下，plot()函數從點到點繪製一條線。
#
# 在圖中從位置 (0,0) 到位置 (6,250) 畫一條線：

# %%
x = np.array([0, 6])
y = np.array([0, 250])

plt.plot(x, y)
plt.show()

# %% [markdown]
# 無線繪圖
#
# 若要僅繪製標記，您可以使用快速字串符號參數“o”，表示“環”。

# %%
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# 多點
#
# 您可以繪製任意數量的點，只需確保兩個軸上的點數相同​​即可。

# %%
x = np.array([1, 2, 6, 8])
y = np.array([3, 8, 1, 10])

plt.plot(x, y)
plt.show()

# %% [markdown]
# 預設 X 點
#
# 如果我們沒有指定 x 軸上的點，它們將獲得預設值 0、1、2、3 等，這取決於 y 點的長度。
#
# 因此，如果我們採用與上面相同的例子，並忽略 x 點，則圖表將如下所示：

# %%
y = np.array([3 , 8 , 1 , 10])

plt.plot(y)
plt.show()

# %% [markdown]
# 標記
#
# 您可以使用關鍵字參數marker來用指定的標記強調每個點：

# %%
plt.plot(y, marker = 'o')
plt.show()

# %%
plt.plot(y, marker = '*')
plt.show()

# %% [markdown]
# Marker	Description
#
# 'o'	Circle
#
# '*'	Star
#
# '.'	Point
#
# ','	Pixel
#
# 'x'	X
#
# 'X'	X (filled)
#
# '+'	Plus
#
# 'P'	Plus (filled)
#
# 's'	Square
#
# 'D'	Diamond
#
# 'd'	Diamond (thin)
#
# 'p'	Pentagon
#
# 'H'	Hexagon
#
# 'h'	Hexagon
#
# 'v'	Triangle Down
#
# '^'	Triangle Up
#
# '<'	Triangle Left
#
# '>'	Triangle Right
#
# '1'	Tri Down
#
# '2'	Tri Up
#
# '3'	Tri Left
#
# '4'	Tri Right
#
# '|'	Vline
#
# '_'	Hline

# %% [markdown]
# 格式字串fmt
#
# 您也可以使用快捷字串符號參數來指定標記。
#
# 此參數也稱為fmt，其語法如下：
#
# marker|line|color

# %%
plt.plot(y, 'o:b')
plt.show()

# %% [markdown]
# 線路參考
#
# '-'	Solid line
#
# ':'	Dotted line
#
# '--'	Dashed line
#
# '-.'	Dashed/dotted line
#
# 顏色參考
#
# 'r'	Red
#
# 'g'	Green
#
# 'b'	Blue
#
# 'c'	Cyan
#
# 'm'	Magenta
#
# 'y'	Yellow
#
# 'k'	Black
#
# 'w'	White

# %% [markdown]
# 標記大小
#
# 您可以使用關鍵字參數markersize或更短的版本ms來設定標記的大小：

# %%
plt.plot(y, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# 標記顏色
#
# 您可以使用關鍵字參數markeredgecolor或更短的參數來設定標記 邊緣mec的顏色

# %%
plt.plot(y, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# 您可以使用關鍵字參數markerfacecolor或更短的參數mfc來設定標記邊緣內的顏色：

# %%
plt.plot(y, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# 線型
#
# 您可以使用關鍵字參數linestyle或更短的參數ls來變更繪製線的樣式：

# %%
plt.plot(y, linestyle = 'dotted')
plt.show()

# %% [markdown]
# 線條顏色
#
# 您可以使用關鍵字參數color或更短的參數c來設定線條的顏色：

# %%
plt.plot(y, color = 'r')
plt.show()

# %% [markdown]
# 線寬
#
# 您可以使用關鍵字參數linewidth或更短的參數lw來改變線的寬度。
#
# 該值是一個浮點數，以點為單位：

# %%
plt.plot(y , linewidth = '20.5')
plt.show()

# %% [markdown]
# 多行
#
# plt.plot()只需添加更多函數即可繪製任意數量的線條：

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])

x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1)
plt.plot(x2, y2)

plt.show()

# %% [markdown]
# 為繪圖建立標籤
#
# 使用 Pyplot，您可以使用xlabel()和 ylabel()函數為 x 軸和 y 軸設定標籤。

# %%
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.plot(x1, y1)
plt.plot(x2, y2)

plt.show()

# %% [markdown]
# 為情節創建標題
#
# 使用 Pyplot，您可以使用title()函數為圖表設定標題。

# %%
plt.title('Graph')

plt.plot(x1, y1)

plt.show()

# %% [markdown]
# 設定標題和標籤的字體屬性
#
# 您可以使用、和fontdict中的參數 來設定標題和標籤的字體屬性。xlabel()ylabel()title()

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }


plt.title('Graph', fontdict = font)

plt.plot(x1, y1)

plt.show()

# %% [markdown]
# 定位標題
#
# 您可以使用loc參數來 title()定位標題。
#
# 合法值為：「left」、「right」和「center」。預設值為‘center’。

# %%
plt.title('Graph', loc = 'left')

plt.plot(x1, y1)

plt.show()

# %% [markdown]
# 在繪圖中新增網格線
#
# 使用 Pyplot，您可以使用grid()函數在圖中新增網格線。

# %%
plt.plot(x1, y1)   

plt.grid()

plt.show()

# %% [markdown]
# 指定要顯示的網格線
#
# 您可以使用函數axis中的參數grid()來指定要顯示哪些網格線。
#
# 合法值為：「x」、「y」和「both」。預設值為“both”。

# %%
plt.plot(x1, y1)

plt.grid(axis = 'x')

plt.show()

# %% [markdown]
# 顯示多個圖
#
# 利用subplot()函數可以在一個圖中繪製多個圖
#
# subplot() 函數
#
# 此subplot()函數採用三個參數來描述圖形的佈局。
#
# 佈局按行和列組織，由第一個 和第二個參數表示。
#
# 第三個參數代表目前圖的索引。

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x, y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x, y)

plt.show()

# %% [markdown]
# 超級標題
#
# 您可以使用下列函數為整個圖形新增標題suptitle()
#
# 也就是全部圖片的總標題

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x, y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x, y)

plt.suptitle('Graph')
plt.show()

# %% [markdown]
# 建立散點圖
#
# 使用Pyplot，您可以使用scatter()函數繪製散佈圖。
#
# 此scatter()函數為每個觀察結果繪製一個點。它需要兩個相同長度的數組，一個用於 x 軸的值，一個用於 y 軸的值：

# %%
x = np.array([5,7,8,5,6,7,9,2,3,4,4,4,2,6,3,6,8,6])
y = np.array([7,4,3,9,1,3,2,5,2,4,8,7,1,6,4,9,7,8])

plt.scatter(x, y)

plt.show()

# %% [markdown]
# 為每個點著色
#
# 您甚至可以使用顏色數組作為 c參數的值為每個點設定特定的顏色：

# %%
x = np.array([4 , 5 , 7 , 8])
y = np.array([5 , 9 , 2 , 3])

colors = np.array(["red", "green", "blue", "yellow"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# 尺寸
#
# 您可以使用參數來改變點的大小 s。
#
# 與顏色一樣，確保大小數組的長度與 x 軸和 y 軸的陣列長度相同：

# %%
sizes = np.array([100 , 200 , 20 , 10])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# 阿爾法
#
# 您可以使用參數調整點的透明度 alpha。
#
# 與顏色一樣，確保大小數組的長度與 x 軸和 y 軸的陣列長度相同：

# %%
plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# 建立長條圖
#
# 使用 Pyplot，您可以使用該bar()函數繪製長條圖：

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y)

plt.show()

# %% [markdown]
# 單槓
#
# 如果您希望長條圖水平顯示而不是垂直顯示，請使用下列barh()函數：

# %%
plt.barh(x, y)

plt.show()

# %% [markdown]
# 建立直方圖
#
# 在 Matplotlib 中，我們使用hist()函數來建立直方圖。
#
# 該hist()函數將使用數字數組來建立直方圖，該數組作為參數傳送到函數中。
#
# 為簡單起見，我們使用 NumPy 隨機產生一個包含 250 個值的數組，其中值集中在 170 左右，標準差為 10 。

# %%
x = np.random.normal(170 , 10 , 250)

print(x)
# Out:
# [169.92849905 170.47734744 165.66418499 174.78165411 184.19422552
#  174.90695887 172.12390015 168.18134658 171.90377095 175.14423817
#  156.48607552 162.27966729 171.27017887 155.74793421 179.22255906
#  160.65964404 170.22257603 173.24406904 174.53950134 168.3760323
#  167.70019679 172.64801166 156.13135566 162.24625077 163.50475322
#  193.48968781 150.90700525 166.50484505 176.01756793 179.6951331
#  157.19016612 179.29137298 173.69522705 167.13897789 178.00048693
#  169.44832741 158.29864002 175.43832874 159.68608034 175.67870973
#  167.49534566 163.51089517 161.2627638  159.64577864 172.14299305
#  166.11959286 168.40405729 160.28247086 184.14014213 181.72823459
#  169.24136987 166.97401359 165.45493188 175.51464506 167.71134626
#  178.56534185 174.20761051 158.44159565 175.58009224 178.65401418
#  159.1579541  166.81630871 161.58874676 168.28581771 160.45544773
#  172.93470901 163.74945615 159.93782932 160.49090705 175.55094408
# ...

# %%
plt.hist(x)

plt.show()

# %% [markdown]
# 創建圓餅圖
#
# 使用Pyplot，你可以使用pie()函數繪製餅圖：

# %%
x = np.array([35, 25, 25, 15])

plt.pie(x)

plt.show()

# %% [markdown]
# 標籤
#
# 使用參數為圓餅圖新增標籤labels。
#
# 這個labels參數必須是一個數組，每個楔形都有一個標籤：

# %%
labels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(x, labels = labels)

plt.show()

# %% [markdown]
# 起始角度
#
# 如上所述，預設起始角度在 x 軸，但您可以透過指定 startangle參數來變更起始角度。
#
# 此startangle參數以度為單位定義角度，預設角度為 0：

# %%
plt.pie(x , labels = labels, startangle = 90)

plt.show()

# %% [markdown]
# Explode
#
# 也許你想讓其中一個楔子脫穎而出？該 explode參數允許您這樣做。
#
# 如果指定了該explode參數，且不是None，則該參數必須是數組，每個楔形都有一個值。
#
# 每個值代表每個楔形距離中心的距離：

# %%
myexplode = [0.2, 0, 0, 0]

plt.pie(x, labels = labels, explode = myexplode)

plt.show()

# %% [markdown]
# 陰影
#
# shadows透過將參數設為True：為餅圖新增陰影 ：

# %%
shadow = [True, False, False, False]

plt.pie(x, labels = labels, explode = myexplode, shadow = shadow)

plt.show()

# %% [markdown]
# 清單
#
# 要添加每個楔形的解釋列表，請使用以下legend()函數：

# %%
plt.pie(x, labels = labels, explode = myexplode, shadow = shadow)
plt.legend()

plt.show()
